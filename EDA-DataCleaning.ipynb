# %% [markdown]
# # 🔍 Exploratory Data Analysis (EDA) & Data Cleaning: Amazon Sales Dataset

# %% [markdown]
# <small>
#
# **🔧 Step 0: Imports & Data Loading**
#
# </small>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Display settings
pd.set_option('display.max_colwidth', None)
sns.set(style="whitegrid")

# Load data
df = pd.read_csv("data/original_data.csv")
df_raw = df.copy()  # Backup original

# %% [markdown]
# <small>
#
# **🔍 Step 1: Initial Data Exploration**
#
# </small>

# %%
# Basic structure
print("Shape of data:", df.shape)
display(df.head(2))
df.info()
df.describe()
# Out:
# Shape of data: (1465, 16)
#    product_id  \
# 0  B07JW9H4J1
# 1  B098NS6PVG
#
#                                                                                                                                                                                         product_name  \
# 0                                 Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)
#
#                                                                             category  \
# 0  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 1  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
#
# ...

# %%
# Check unique categories
print("Unique product categories:\n", df['category'].unique())
# Out:
# Unique product categories:
#  ['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'
#  'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables'
#  'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions'
#  'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls'
#  'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions'
#  'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables'
#  'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts'
#  'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables'
#  'Electronics|HomeTheater,TV&Video|Projectors'
#  'Electronics|HomeAudio|Accessories|Adapters'
#  'Electronics|HomeTheater,TV&Video|SatelliteEquipment|SatelliteReceivers'
# ...

# %% [markdown]
# <small>
#
# ## 🧠 Observations:
#
# - **Data Types:**
#   Many columns have `dtype=object` including numeric-looking ones.
#
# - **Missing Values:**
#   `rating_count` has 2 missing values.
#
# - **Category Structure:**
#   `category` contains hierarchical info separated by `|`.
#
#   </small>

# %% [markdown]
# <small>
#
# **🔁 Step 2: Data Cleaning & Type Conversion**
#
# </small>

# %%
# Clean and Convert Price and Rating Columns
df['discounted_price'] = df['discounted_price'].str.replace('₹','')
df['discounted_price'] = df['discounted_price'].str.replace(',','')
df['discounted_price'] = pd.to_numeric(df['discounted_price'], errors='coerce') #errors='coerce' forces invalid entries (e.g., "N/A") to become NaN.

df['actual_price'] = df['actual_price'].str.replace('₹','')
df['actual_price'] = df['actual_price'].str.replace(',','')
df['actual_price'] = pd.to_numeric(df['actual_price'], errors='coerce')

df['discount_percentage'] = df['discount_percentage'].str.replace('%', '')
df['discount_percentage'] = pd.to_numeric(df['discount_percentage'], errors='coerce') / 100

df['rating'] = df['rating'].str.replace(',','')
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

df['rating_count'] = df['rating_count'].str.replace(',', '')
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce').astype('Int64')

# %%
#Check Data types
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count             Int64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# <small>
#
# **🧹 Step 3: Handling Missing Values**
#
# </small>

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Manual fixes based on external lookups 
df.loc[df['product_id'] == 'B08L12N5H1', 'rating'] = 3.9
df.loc[df['product_id'] == 'B0B94JPY2N', 'rating_count'] = 2201

# Drop rows where rating_count is still missing
df = df.dropna(subset=['rating_count'])

# %% [markdown]
# <small>
#
# **🔁 Step 4: Duplicates Check**
#
# </small>

# %%
duplicates = df.duplicated().sum()
print(f"{duplicates} duplicate found")
# Out:
# 0 duplicate found

# %% [markdown]
# <small>
#
# **📊 Step 5: Outliers & Distribution**
#
# </small>

# %%
# Summary statistics
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1464.000000    1464.000000          1464.000000  1464.000000
# mean        3127.275567    5448.027514             0.476728     4.095833
# std         6946.269985   10877.921405             0.216315     0.290761
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1670.000000             0.500000     4.100000
# 75%         1999.000000    4303.750000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#        rating_count
# count        1464.0
# mean   18284.547814
# std    42741.320641
# min             2.0
# 25%          1188.5
# 50%          5178.5
# 75%        17330.75
# max        426973.0

# %%
 #Visualizing Distributions
def plot_box(column):
    plt.figure(figsize=(8, 1.5))
    sns.boxplot(x=column, data=df, color='skyblue')
    plt.title(f'Boxplot of {column}')
    plt.show()

plot_box('actual_price')
plot_box('discounted_price')
plot_box('discount_percentage')
plot_box('rating_count')
plot_box('rating')

# %% [markdown]
# <small>
#
# **⭐ Step 6: Bayesian Rating**
#
# </small>

# %%
# Weighted Rating Calculation (Bayesian Rating)
C = df['rating'].mean()
m = 100  # Minimum votes to be considered

df['bayesian_rating'] = (
    (df['rating_count'] / (df['rating_count'] + m)) * df['rating'] +
    (m / (df['rating_count'] + m)) * C
)

# %% [markdown]
# <small>
#
# **🗂 Step 7: Expand Category Column**
#
# </small>

# %%
# Split category into subcategories
category_splits = df['category'].str.split('|', expand=True)
for i in range(category_splits.shape[1]):
    df[f'subcategory_{i+1}'] = category_splits[i]

df[['category'] + [f'subcategory_{i+1}' for i in range(category_splits.shape[1])]].head()
# Out:
#                                                                             category  \
# 0  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 1  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 2  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 3  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 4  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
#
#            subcategory_1            subcategory_2       subcategory_3  \
# 0  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 1  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 2  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 3  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 4  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
#
# ...

# %% [markdown]
# <small>
#
# ## ✅ Data Cleaning Summary
#
# ### 🧹 Data Quality Improvements:
# - **Monetary values & percentages**: Cleaned and standardized formats
# - **Data types**: Converted to proper numeric dtypes where applicable
# - **Missing values**: Addressed through manual lookup and strategic dropping
# - **Data integrity**: Checked for duplicates and outliers
#
# ### 📊 Enhanced Features:
# - **Rating system**: Created weighted `bayesian_rating` column
# - **Categories**: Successfully extracted hierarchical categories
#
# </small>
